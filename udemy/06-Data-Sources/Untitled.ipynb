# %%
#Pandas_datareader
import pandas_datareader.data as web

# %%
import datetime

# %%
start = datetime.datetime(2017,1,1)
end = datetime.datetime(2019,1,1)

# %%
facebook = web.DataReader('FB','yahoo',start,end)

# %%
facebook.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-01-03  117.839996  115.510002  116.029999  116.860001  20663900
# 2017-01-04  119.660004  117.290001  117.550003  118.690002  19630900
# 2017-01-05  120.949997  118.320000  118.860001  120.669998  19492200
# 2017-01-06  123.879997  120.029999  120.980003  123.410004  28545300
# 2017-01-09  125.430000  123.040001  123.550003  124.900002  22880400
#
#              Adj Close
# Date
# 2017-01-03  116.860001
# 2017-01-04  118.690002
# 2017-01-05  120.669998
# 2017-01-06  123.410004
# 2017-01-09  124.900002

# %%
from pandas_datareader.data import Options

# %%
#not supported anymore
#fb_options = Options('FB','iex')
#options_df = fb_options.get_options_data(expiry=fb_options.expiry_dates[0])

# %%
#Quandl

# %%
import quandl

# %%
quandl.ApiConfig.api_key = "NV86SoEUeEwVy5QJuoJU"

# %%
db_stock = quandl.get("FSE/DBK_X", authtoken="NV86SoEUeEwVy5QJuoJU")

# %%
import matplotlib.pyplot as plt
db_stock[db_stock['Traded Volume'].apply(lambda x: x>40720160)]
# Out:
#               Open    High     Low   Close  Change  Traded Volume  \
# Date
# 2008-09-19  57.190  62.460  55.010  57.500     NaN     41300077.0
# 2016-06-24  13.000  13.950  12.760  13.370     NaN     53702140.0
# 2016-06-27  13.380  13.440  12.070  12.540     NaN     43139093.0
# 2016-09-30  10.050  11.710   9.900  11.570     NaN     56936694.0
# 2016-10-03     NaN  11.710   9.898  11.570     0.7     56936694.0
# 2017-03-20  17.550  17.720  17.040  17.200     NaN     47516877.0
# 2017-03-21  15.460  16.470  15.420  16.010     NaN     41242880.0
# 2017-04-04  15.350  15.600  15.100  15.600     NaN     48469234.0
# 2017-04-24  16.250  16.990  16.250  16.990     NaN     44328930.0
# 2017-06-16  15.180  15.340  14.880  15.000     NaN     41494790.0
# 2018-02-02     NaN  14.256  13.726  13.860     NaN     41388661.0
# 2018-05-29     NaN  10.206   9.705   9.817     NaN     45395234.0
# 2018-05-31     NaN  10.012   9.066   9.157     NaN     60614123.0
# ...
